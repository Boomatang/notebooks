# %% [markdown]
# # RHOAM Checks
# Commands here is what I carry out when doing a rebase.

# %%
import os
from pathlib import Path

repo = Path.home().joinpath('go/src/github.com/integr8ly/integreatly-operator')
os.chdir(repo)
os.getcwd()
# Out:
# '/home/jimfitz/go/src/github.com/integr8ly/integreatly-operator'

# %%
! make code/check
# Out:
# golint ./pkg/... | grep -v  "comment on" | grep -v "or be unexported"
# pkg/addon/operator_run.go:84:9: if block ends with a return statement, so drop this else and outdent its block
# pkg/addon/operator_run.go:120:28: error strings should not be capitalized or end with punctuation or a newline
# pkg/addon/operator_run_test.go:21:5: error var genericError should have name of the form errFoo
# pkg/addon/parameters_test.go:429:9: if block ends with a return statement, so drop this else and outdent its block
# pkg/config/manager.go:37:6: type name will be used as config.ConfigReadWriter by other packages, and that stutters; consider calling this ReadWriter
# pkg/config/manager.go:57:6: type name will be used as config.ConfigReadable by other packages, and that stutters; consider calling this Readable
# pkg/metrics/metrics.go:313:9: if block ends with a return statement, so drop this else and outdent its block
# pkg/metrics/metrics.go:426:6: func GetApiClient should be GetAPIClient
# pkg/products/reconciler.go:92:2: var oauthHttpClient should be oauthHTTPClient
# pkg/products/cloudresources/reconciler.go:473:12: should omit 2nd value from range; this loop is equivalent to `for tier := range ...`
# pkg/products/cloudresources/reconciler.go:589:11: should omit 2nd value from range; this loop is equivalent to `for key := range ...`
# pkg/products/marin3r/apiUsagePrometheusRules.go:174:10: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/marin3r/limitadorClient.go:30:61: exported method GetLimitsByName returns unexported type []marin3r.limitadorLimit, which can be annoying to use
# pkg/products/marin3r/rateLimitService.go:138:10: if block ends with a return statement, so drop this else and outdent its block
# pkg/products/marin3r/rateLimitService.go:382:51: exported func GetRateLimitFromConfig returns unexported type *marin3r.limitadorLimit, which can be annoying to use
# pkg/products/marin3r/rateLimitService.go:419:1: context.Context should be the first parameter of a function
# pkg/products/marin3r/config/config.go:14:2: const ManagedApiServiceQuota should be ManagedAPIServiceQuota
# pkg/products/monitoringcommon/alertmanagerConfig.go:37:6: func getSmtpHost should be getSMTPHost
# pkg/products/monitoringcommon/alertmanagerConfig.go:45:6: func getSmtpPort should be getSMTPPort
# pkg/products/monitoringcommon/alertmanagerConfig.go:53:6: func getSmtpUsername should be getSMTPUsername
# pkg/products/monitoringcommon/alertmanagerConfig.go:61:6: func getSmtpPassword should be getSMTPPassword
# pkg/products/monitoringcommon/alertmanagerConfig.go:176:2: don't use underscores in Go names; var cluster_vars should be clusterVars
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:190:2: don't use underscores in Go names; var cluster_vars should be clusterVars
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:367:5: don't use underscores in Go names; var cluster_vars should be clusterVars
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:615:5: var emptySmtpSecret should be emptySMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:625:5: var invalidSmtpSecret should be invalidSMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:634:5: var correctSmtpSecret should be correctSMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:681:5: var emptySmtpSecret should be emptySMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:691:5: var invalidSmtpSecret should be invalidSMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:700:5: var correctSmtpSecret should be correctSMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:747:5: var emptySmtpSecret should be emptySMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:757:5: var invalidSmtpSecret should be invalidSMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:766:5: var correctSmtpSecret should be correctSMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:813:5: var emptySmtpSecret should be emptySMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:823:5: var invalidSmtpSecret should be invalidSMTPSecret
# pkg/products/monitoringcommon/alertmanagerConfig_test.go:832:5: var correctSmtpSecret should be correctSMTPSecret
# pkg/products/monitoringcommon/dashboardHelper.go:11:72: func parameter containerCpuMetric should be containerCPUMetric
# pkg/products/monitoringcommon/dashboardHelper_test.go:41:2: var containerCpuMetric should be containerCPUMetric
# pkg/products/monitoringcommon/dashboards/clusterResources.go:6:84: func parameter containerCpuMetric should be containerCPUMetric
# pkg/products/monitoringcommon/dashboards/resourceByNamespace.go:6:80: func parameter containerCpuMetric should be containerCPUMetric
# pkg/products/monitoringcommon/dashboards/resourceByPod.go:6:88: func parameter containerCpuMetric should be containerCPUMetric
# pkg/products/monitoringspec/reconciler_test.go:248:2: var managedApiInstallation should be managedAPIInstallation
# pkg/products/monitoringspec/reconciler_test.go:383:2: var managedApiInstallation should be managedAPIInstallation
# pkg/products/observability/reconciler.go:624:2: var containerCpuMetric should be containerCPUMetric
# pkg/products/observability/reconciler.go:1057:134: method parameter roleApiGroup should be roleAPIGroup
# pkg/products/observability/reconciler.go:1111:109: method parameter roleApiGroup should be roleAPIGroup
# pkg/products/observability/reconciler_test.go:36:2: error var genericError should have name of the form errFoo
# pkg/products/rhsso/reconciler_test.go:280:3: struct field ApiUrl should be APIURL
# pkg/products/rhsso/reconciler_test.go:761:3: struct field ApiUrl should be APIURL
# pkg/products/rhssocommon/reconciler.go:288:3: var clientId should be clientID
# pkg/products/rhssocommon/reconciler.go:433:1: context.Context should be the first parameter of a function
# pkg/products/rhssocommon/reconciler.go:523:1: context.Context should be the first parameter of a function
# pkg/products/rhssocommon/reconciler.go:668:1: context.Context should be the first parameter of a function
# pkg/products/rhssocommon/reconciler_test.go:227:3: struct field ApiUrl should be APIURL
# pkg/products/rhssocommon/reconciler_test.go:1262:14: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1266:13: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1319:15: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1323:15: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1326:14: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1330:13: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1387:15: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1391:15: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1394:14: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1398:13: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1455:15: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1459:15: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1462:14: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssocommon/reconciler_test.go:1466:13: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/rhssouser/reconciler.go:97:212: func parameter apiUrl should be apiURL
# pkg/products/rhssouser/reconciler.go:486:10: if block ends with a return statement, so drop this else and outdent its block
# pkg/products/rhssouser/reconciler.go:581:1: context.Context should be the first parameter of a function
# pkg/products/rhssouser/reconciler.go:622:1: context.Context should be the first parameter of a function
# pkg/products/rhssouser/reconciler_test.go:123:3: struct field ApiUrl should be APIURL
# pkg/products/rhssouser/reconciler_test.go:293:3: struct field ApiUrl should be APIURL
# pkg/products/rhssouser/reconciler_test.go:605:3: struct field ApiUrl should be APIURL
# pkg/products/rhssouser/reconciler_test.go:943:3: struct field ApiUrl should be APIURL
# pkg/products/threescale/objects_test.go:96:5: var threeScaleApiCastSecret should be threeScaleAPICastSecret
# pkg/products/threescale/prometheusRules.go:16:1: context.Context should be the first parameter of a function
# pkg/products/threescale/prometheusRules.go:20:2: var containerCpuMetric should be containerCPUMetric
# pkg/products/threescale/reconciler.go:88:2: const systemMasterApiCastSecretName should be systemMasterAPICastSecretName
# pkg/products/threescale/reconciler.go:824:10: if block ends with a return statement, so drop this else and outdent its block
# pkg/products/threescale/reconciler.go:1441:22: method updateKeycloakUsersAttributeWith3ScaleUserId should be updateKeycloakUsersAttributeWith3ScaleUserID
# pkg/products/threescale/reconciler.go:1893:10: if block ends with a return statement, so drop this else and outdent its block
# pkg/products/threescale/reconciler.go:2838:20: should omit 2nd value from range; this loop is equivalent to `for envVarName := range ...`
# pkg/products/threescale/three_scale_client.go:18:6: type name will be used as threescale.ThreeScaleInterface by other packages, and that stutters; consider calling this Interface
# pkg/products/threescale/three_scale_client.go:53:35: interface method parameter accountId should be accountID
# pkg/products/threescale/three_scale_client.go:53:46: interface method parameter userId should be userID
# pkg/products/threescale/three_scale_client.go:71:69: exported func NewThreeScaleClient returns unexported type *threescale.threeScaleClient, which can be annoying to use
# pkg/products/threescale/three_scale_client.go:195:9: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/products/threescale/three_scale_client.go:668:63: method parameter accountId should be accountID
# pkg/products/threescale/three_scale_client.go:668:74: method parameter userId should be userID
# pkg/products/threescale/three_scale_client.go:754:63: method parameter accountId should be accountID
# pkg/products/threescale/types.go:14:2: struct field Id should be ID
# pkg/products/threescale/types.go:30:2: struct field Id should be ID
# pkg/products/threescale/types.go:35:2: struct field ClientId should be ClientID
# pkg/products/threescale/types.go:41:2: struct field AccountId should be AccountID
# pkg/products/threescale/types.go:48:2: struct field CallbackUrl should be CallbackURL
# pkg/products/threescale/types.go:62:2: struct field Id should be ID
# pkg/products/threescale/types.go:68:2: struct field Id should be ID
# pkg/products/threescale/types.go:77:2: struct field Id should be ID
# pkg/products/threescale/types.go:87:2: struct field Id should be ID
# pkg/resources/cluster.go:92:6: func GetExternalClusterId should be GetExternalClusterID
# pkg/resources/limitRange.go:18:2: struct field CpuRequest should be CPURequest
# pkg/resources/limitRange.go:19:2: struct field CpuLimit should be CPULimit
# pkg/resources/metrics.go:162:6: func CreateSmtpSecretExists should be CreateSMTPSecretExists
# pkg/resources/metrics.go:186:6: func CreateAddonManagedApiServiceParametersExists should be CreateAddonManagedAPIServiceParametersExists
# pkg/resources/metrics.go:778:6: func CreateRedisCpuUsageAlerts should be CreateRedisCPUUsageAlerts
# pkg/resources/rhssoClient.go:21:1: context.Context should be the first parameter of a function
# pkg/resources/sop_url.go:5:2: const sopUrlAddonManagedApiServiceParametersExists should be sopURLAddonManagedAPIServiceParametersExists
# pkg/resources/sop_url.go:6:2: const sopUrlRhoamBase should be sopURLRhoamBase
# pkg/resources/sop_url.go:7:2: const sopUrlPostgresInstanceUnavailable should be sopURLPostgresInstanceUnavailable
# pkg/resources/sop_url.go:8:2: const sopUrlPostgresConnectionFailed should be sopURLPostgresConnectionFailed
# pkg/resources/sop_url.go:9:2: const sopUrlRedisCacheUnavailable should be sopURLRedisCacheUnavailable
# pkg/resources/sop_url.go:10:2: const sopUrlRedisConnectionFailed should be sopURLRedisConnectionFailed
# pkg/resources/sop_url.go:11:2: const sopUrlPostgresResourceStatusPhasePending should be sopURLPostgresResourceStatusPhasePending
# pkg/resources/sop_url.go:12:2: const sopUrlPostgresResourceStatusPhaseFailed should be sopURLPostgresResourceStatusPhaseFailed
# pkg/resources/sop_url.go:13:2: const sopUrlRedisResourceStatusPhasePending should be sopURLRedisResourceStatusPhasePending
# pkg/resources/sop_url.go:14:2: const sopUrlRedisResourceStatusPhaseFailed should be sopURLRedisResourceStatusPhaseFailed
# pkg/resources/sop_url.go:15:2: const sopUrlPostgresWillFill should be sopURLPostgresWillFill
# pkg/resources/sop_url.go:16:2: const sopUrlPostgresFreeableMemoryLow should be sopURLPostgresFreeableMemoryLow
# pkg/resources/sop_url.go:17:2: const sopUrlRedisMemoryUsageHigh should be sopURLRedisMemoryUsageHigh
# pkg/resources/sop_url.go:18:2: const sopUrlPostgresCpuUsageHigh should be sopURLPostgresCPUUsageHigh
# pkg/resources/sop_url.go:19:2: const sopUrlRedisCpuUsageHigh should be sopURLRedisCPUUsageHigh
# pkg/resources/sop_url.go:20:2: const sopUrlRedisServiceMaintenanceCritical should be sopURLRedisServiceMaintenanceCritical
# pkg/resources/sop_url.go:21:2: const SopUrlEndpointAvailableAlert should be SopURLEndpointAvailableAlert
# pkg/resources/sop_url.go:22:2: const SopUrlAlertsAndTroubleshooting should be SopURLAlertsAndTroubleshooting
# pkg/resources/sop_url.go:23:2: const sopUrlCloudResourceDeletionStatusFailed should be sopURLCloudResourceDeletionStatusFailed
# pkg/resources/sop_url.go:24:2: const sopUrlSendGridSmtpSecretExists should be sopURLSendGridSMTPSecretExists
# pkg/resources/sop_url.go:25:2: const SopUrlDeadMansSnitchSecretExists should be SopURLDeadMansSnitchSecretExists
# pkg/resources/sop_url.go:26:2: const SopUrlMarin3rEnvoyApicastProductionContainerDown should be SopURLMarin3rEnvoyApicastProductionContainerDown
# pkg/resources/sop_url.go:27:2: const SopUrlMarin3rEnvoyApicastStagingContainerDown should be SopURLMarin3rEnvoyApicastStagingContainerDown
# pkg/resources/sop_url.go:28:2: const SopUrlOperatorInstallDelayed should be SopURLOperatorInstallDelayed
# pkg/resources/sop_url.go:29:2: const SopUrlUpgradeExpectedDurationExceeded should be SopURLUpgradeExpectedDurationExceeded
# pkg/resources/sop_url.go:30:2: const SopUrlRHOAMIsInReconcilingErrorState should be SopURLRHOAMIsInReconcilingErrorState
# pkg/resources/sop_url.go:31:2: const SopUrlRHOAMCloudResourceOperatorMetricsServiceEndpointDown should be SopURLRHOAMCloudResourceOperatorMetricsServiceEndpointDown
# pkg/resources/sop_url.go:32:2: const SopUrlRHOAMCloudResourceOperatorVPCActionFailed should be SopURLRHOAMCloudResourceOperatorVPCActionFailed
# pkg/resources/sop_url.go:33:2: const SopUrlRHOAMThreeScaleApicastProductionServiceEndpointDown should be SopURLRHOAMThreeScaleApicastProductionServiceEndpointDown
# pkg/resources/sop_url.go:34:2: const SopUrlRHOAMThreeScaleApicastStagingServiceEndpointDown should be SopURLRHOAMThreeScaleApicastStagingServiceEndpointDown
# pkg/resources/sop_url.go:35:2: const SopUrlRHOAMThreeScaleBackendListenerServiceEndpointDown should be SopURLRHOAMThreeScaleBackendListenerServiceEndpointDown
# pkg/resources/sop_url.go:36:2: const SopUrlRHOAMThreeScaleZyncServiceEndpointDown should be SopURLRHOAMThreeScaleZyncServiceEndpointDown
# pkg/resources/sop_url.go:37:2: const SopUrlRHOAMThreeScaleZyncDatabaseServiceEndpointDown should be SopURLRHOAMThreeScaleZyncDatabaseServiceEndpointDown
# pkg/resources/sop_url.go:38:2: const SopUrlThreeScaleBackendWorkerPod should be SopURLThreeScaleBackendWorkerPod
# pkg/resources/sop_url.go:39:2: const SopUrlThreeScaleAdminUIBBT should be SopURLThreeScaleAdminUIBBT
# pkg/resources/sop_url.go:40:2: const SopUrlThreeScaleDeveloperUIBBT should be SopURLThreeScaleDeveloperUIBBT
# pkg/resources/sop_url.go:41:2: const SopUrlThreeScaleSystemAdminUIBBT should be SopURLThreeScaleSystemAdminUIBBT
# pkg/resources/sop_url.go:42:2: const SopUrlPodDistributionIncorrect should be SopURLPodDistributionIncorrect
# pkg/resources/sop_url.go:43:2: const SopUrlSloRhssoAvailabilityAlert should be SopURLSloRhssoAvailabilityAlert
# pkg/resources/sop_url.go:44:2: const SopUrlSloUserSsoAvailabilityAlert should be SopURLSloUserSsoAvailabilityAlert
# pkg/resources/sop_url.go:45:2: const SopUrlTestFireAlerts should be SopURLTestFireAlerts
# pkg/resources/sop_url.go:46:2: const SopUrlRHOAMServiceDefinition should be SopURLRHOAMServiceDefinition
# pkg/resources/sop_url.go:47:2: const SopUrlDnsBypassThreeScaleAdminUI should be SopURLDNSBypassThreeScaleAdminUI
# pkg/resources/sop_url.go:48:2: const SopUrlDnsBypassThreeScaleDeveloperUI should be SopURLDNSBypassThreeScaleDeveloperUI
# pkg/resources/sop_url.go:49:2: const SopUrlDnsBypassThreeScaleSystemAdminUI should be SopURLDNSBypassThreeScaleSystemAdminUI
# pkg/resources/sop_url.go:50:2: const SopUrlKeycloakInstanceNotAvailable should be SopURLKeycloakInstanceNotAvailable
# pkg/resources/sop_url.go:51:2: const SopUrlCriticalMetricsMissing should be SopURLCriticalMetricsMissing
# pkg/resources/sop_url.go:52:2: const SopUrlClusterSchedulableResourcesLow should be SopURLClusterSchedulableResourcesLow
# pkg/resources/sop_url.go:53:2: const SopUrlKubePersistentVolumeFillingUp4h should be SopURLKubePersistentVolumeFillingUp4h
# pkg/resources/sop_url.go:54:2: const SopUrlKubePersistentVolumeFillingUp should be SopURLKubePersistentVolumeFillingUp
# pkg/resources/sop_url.go:55:2: const SopUrlPersistentVolumeErrors should be SopURLPersistentVolumeErrors
# pkg/resources/sop_url.go:56:2: const SopApiManagementTenantCRFailed should be SopAPIManagementTenantCRFailed
# pkg/resources/sop_url.go:57:2: const SopUrlRHOAMCloudResourceOperatorMetricsMissing should be SopURLRHOAMCloudResourceOperatorMetricsMissing
# pkg/resources/backup/backup_executor.go:14:6: type name will be used as backup.BackupExecutor by other packages, and that stutters; consider calling this Executor
# pkg/resources/catalogsource/catalogsource_client.go:16:6: type name will be used as catalogsource.CatalogSourceClientInterface by other packages, and that stutters; consider calling this ClientInterface
# pkg/resources/catalogsource/catalogsource_client.go:20:6: type name will be used as catalogsource.CatalogSourceClient by other packages, and that stutters; consider calling this Client
# pkg/resources/custom-domain/custom-domain.go:1:1: don't use an underscore in package name
# pkg/resources/custom-domain/custom-domain_test.go:1:1: don't use an underscore in package name
# pkg/resources/custom-domain/prometheusRules.go:1:1: don't use an underscore in package name
# pkg/resources/custom-smtp/custom-smtp.go:1:1: don't use an underscore in package name
# pkg/resources/custom-smtp/custom-smtp.go:24:6: type CustomSmtp should be CustomSMTP
# pkg/resources/custom-smtp/custom-smtp.go:39:2: var customSmtp should be customSMTP
# pkg/resources/custom-smtp/custom-smtp_test.go:1:1: don't use an underscore in package name
# pkg/resources/marketplace/manager.go:25:6: type name will be used as marketplace.MarketplaceInterface by other packages, and that stutters; consider calling this Interface
# pkg/resources/poddistribution/poddistribution.go:55:10: if block ends with a return statement, so drop this else and outdent its block
# pkg/resources/quota/quota.go:71:6: type name will be used as quota.QuotaProductConfig by other packages, and that stutters; consider calling this ProductConfig
# pkg/resources/quota/quota.go:106:10: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/resources/quota/quota.go:215:10: should replace errors.New(fmt.Sprintf(...)) with fmt.Errorf(...)
# pkg/resources/quota/quota.go:251:9: should omit 2nd value from range; this loop is equivalent to `for i := range ...`
# pkg/resources/quota/quota.go:299:6: func checkApiManager should be checkAPIManager
# pkg/resources/quota/quota_test.go:29:3: struct field QuotaId should be QuotaID
# pkg/resources/ratelimit/envoy.go:38:89: exported func NewEnvoyProxyServer returns unexported type *ratelimit.envoyProxyServer, which can be annoying to use
# pkg/resources/rhmi/rhmi.go:13:1: context.Context should be the first parameter of a function
# pkg/resources/sts/sts.go:29:2: const CredsS3AccessKeyId should be CredsS3AccessKeyID
# pkg/resources/user/userHelper.go:78:3: var userId should be userID
# pkg/resources/user/userHelper.go:89:6: func name will be used as user.UserInExclusionGroup by other packages, and that stutters; consider calling this InExclusionGroup
# go vet ./...

# %%
! make code/gen
# Out:
# GO111MODULE=off go get github.com/matryer/moq
# GOBIN=/home/jimfitz/go/src/github.com/integr8ly/integreatly-operator/bin go install sigs.k8s.io/controller-tools/cmd/controller-gen@v0.8.0
# /home/jimfitz/go/src/github.com/integr8ly/integreatly-operator/bin/controller-gen object:headerFile="hack/boilerplate.go.txt" paths="./..."
# /home/jimfitz/go/src/github.com/integr8ly/integreatly-operator/bin/controller-gen rbac:roleName=manager-role crd webhook paths="./..." output:crd:artifacts:config=config/crd/bases
# mv ./config/crd/bases/integreatly.org_apimanagementtenants.yaml ./config/crd-sandbox/bases

# %%
! make vendor/check
# Out:
# go mod tidy
# go: downloading github.com/integr8ly/keycloak-client v0.1.9
# go mod vendor
# git diff --exit-code vendor/
# git diff --exit-code go.sum

# %%
! make code/compile
# Out:
# GO111MODULE=off go get github.com/matryer/moq
# /home/jimfitz/go/src/github.com/integr8ly/integreatly-operator/bin/controller-gen object:headerFile="hack/boilerplate.go.txt" paths="./..."
# /home/jimfitz/go/src/github.com/integr8ly/integreatly-operator/bin/controller-gen rbac:roleName=manager-role crd webhook paths="./..." output:crd:artifacts:config=config/crd/bases
# mv ./config/crd/bases/integreatly.org_apimanagementtenants.yaml ./config/crd-sandbox/bases

# %%
! make scorecard/compile
# Out:
# go build -o scorecard-test-kuttl test/scorecard/main.go

# %%
! make test-cases/lint
# Out:
# cd test-cases/ && npm install
#  .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] | preinstall:integreatly-test-cases: info lifecycle integr[ .................] / loadIdealTree:loadAllDepsIntoIdealTree: sill install loa[   ...............] \ loadDep:uuid: sill install loadAllDepsIntoIdealTree[   ...............] \ loadDep:os-tmpdir: sill install loadAllDepsIntoIdealTree[   ...............] \ loadDep:url-parse-lax: sill install loadAllDepsIntoIdeal[   ...............] \ loadDep:write-file-atomic: sill install loadAllDepsIntoI[   ...............] \ loadDep:through: sill install loadAllDepsIntoIdealTree[   ...............] \ loadDep:which: sill install loadAllDepsIntoIdealTree[   ...............] \ loadDep:xdg-basedir: sill install loadAllDepsIntoIdealTr[   ...............] \ loadDep:path-is-absolute: sill install loadAllDepsIntoId[    ..............] \ loadDep:strip-ansi: sill install loadAllDepsIntoIdealTre[       ...........] - postinstall: sill install executeActions[         .........] | prepare:test-cases: info lifecycle integreatly-test-case
# npm WARN integreatly-test-cases@0.0.0 No license field.
#
# 0m[         .........] / prepare:test-cases: WARN integreatly-test-cases@0.0.0 No[         .........] / prepare:test-cases: WARN integreatly-test-cases@0.0.0 No
#
# 7 packages are looking for funding
#   run `npm fund` for details
#
# found 133 vulnerabilities (7 low, 38 moderate, 70 high, 18 critical)
#   run `npm audit fix` to fix them, or `npm audit` for details
# 7m         .........] | prepare:test-cases: timing audit body Completed in 6mscd test-cases/ && npm run lint || \
# 	(echo -e "\nRun 'make test-cases/fix' to automatically fix all lint issues\n"; exit 23)
#
# > integreatly-test-cases@0.0.0 lint /home/jimfitz/go/src/github.com/integr8ly/integreatly-operator/test-cases
# > prettier --check '**/*.*' && ./tools.sh lint && tslint -p .
#
# Checking formatting...
# .prettierrc.jsoncommon/general-guidelines.mdfixtures/test-template.mdpackage-lock.jsonpackage.jsonREADME.mdtests/alerts/c01-verify-alerts-are-not-firing-apart-from-deadmansswitch.mdtests/alerts/c02-verify-that-correct-allerts-have-been-installed.mdtests/alerts/c03-verify-that-alerting-mechanism-works.mdtests/alerts/c04-verify-alerts-exist.mdtests/alerts/c05b-verify-alerts-are-exposed-and-no-critical-alerts-have-fired.mdtests/alerts/c08b-verify-alert-links-to-sops.mdtests/alerts/c10b-verify-additional-blackboxtargets.mdtests/alerts/c11b-verify-rhoam-install-alert-is-firing.mdtests/alerts/c14b-verify-3scale-uibbt-alerts.mdtests/alerts/c17b-verify-rhoam-upgrade-alerts-are-present.mdtests/alerts/c18-validate-api-usage-alerts.mdtests/alerts/c19-validate-creation-of-invalid-username-triggers-alert.mdtests/authorization/b01b-verify-that-the-users-can-login-in-all-products.mdtests/authorization/b03b-verify-rhoam-developer-user-permissions-are-correct.mdtests/authorization/b04b-verify-dedicated-admin-user-permissions-are-correct.mdtests/authorization/b06-verify-default-email-address.mdtests/authorization/b08b-verify-user-rhsso-permissions.mdtests/authorization/b09-verify-dedicated-admin-users-are-synced-with-user-sso.mdtests/backup-restore/j03b-verify-that-namespaces-get-recreated-by-the-integreatlyoper.mdtests/backup-restore/j05b-verify-3scale-backup-and-restore.mdtests/backup-restore/j07b-verify-cluster-sso-backup-and-restore.mdtests/backup-restore/j08b-verify-user-sso-backup-and-restore.mdtests/dashboards/e01-verify-that-grafana-dashboard-is-accessible.mdtests/dashboards/e02-verify-that-all-dashboards-are-installed-and-all-the-graphs.mdtests/dashboards/e03-verify-dashboards-exist.mdtests/dashboards/e04b-verify-slo-dashboard.mdtests/dashboards/e05-verify-that-grafana-route-return-dashboards.mdtests/dashboards/e07b-verify-drill-down-links.mdtests/dashboards/e08b-verify-values-are-correct-in-resource-usage-dashboard.mdtests/dashboards/e09-verify-customer-grafana-route-is-accessible.mdtests/dashboards/e10-validate-updated-grafana-dashboards-and-alerts.mdtests/documentation/i01-verify-release-notes.mdtests/documentation/i02-verify-partial-ag-rate-limits-and-alerts.mdtests/documentation/i03-adding-rhoam.mdtests/documentation/i04-accessing-rhoam.mdtests/documentation/i05-managing-users.mdtests/documentation/i06-verify-aws-info-byoc.mdtests/documentation/i07-overview-of-red-hat-openshift-api-management.mdtests/documentation/i08-deploying-apicast-on-osd.mdtests/documentation/i09-monitoring-the-service.mdtests/documentation/i10-network-policies.mdtests/documentation/i11-verify-modifying-custom-parameters-email.mdtests/documentation/i12-modifying-dynamic-quota.mdtests/documentation/i13-install-rhoam-ocm.mdtests/high-availability/f01-verify-aws-rds-resources-exist-and-are-in-expected-state.mdtests/high-availability/f02-verify-poddisruptionbudgets-exist.mdtests/high-availability/f03-verify-aws-elasticache-resources-exist-and-are-in-expected-s.mdtests/high-availability/f04-verify-aws-s3-resources-exist-and-are-in-expected-state.mdtests/high-availability/f05-verify-replicas-scale-correctly-in-threescale.mdtests/high-availability/f06-verify-replicas-scale-correctly-in-apicurito.mdtests/high-availability/f07-verify-replicas-scale-correctly-in-amq-streams.mdtests/high-availability/f08-verify-replicas-scale-correctly-in-rhsso-and-user-sso.mdtests/installation/a01-verify-that-all-stages-in-the-integreatlyoperator-cr-report.mdtests/installation/a02-all-specific-products-specified-under-the-stages-in-the-inte.mdtests/installation/a03-all-namespaces-have-been-created-with-the-correct-name.mdtests/installation/a05-all-operator-versions-are-correct.mdtests/installation/a06-there-are-no-failed-pvcs.mdtests/installation/a07-all-operand-versions-are-correct.mdtests/installation/a08-verify-all-products-routes-are-created.mdtests/installation/a09-verify-product-subscription-install-plan-type.mdtests/installation/a10-verify-cro-postgres-crs-successful.mdtests/ins ...
# info: linting: automation-jiras
# info: linting: categories
# info: linting: components
# info: linting: duplicate-ids
# info: linting: file-names
# info: linting: sections
# info: linting: tags
# info: linting: environments
# info: linting: mandatory-environment
# info: linting: occurrence
# info: linting: products
# info: linting: targets
# info: linting: all checks succeeded
#
#
#    ╭───────────────────────────────────────────────────────────────╮
#    │                                                               │
#    │      New major version of npm available! 6.14.9 → 9.1.1       │
#    │   Changelog: https://github.com/npm/cli/releases/tag/v9.1.1   │
#    │               Run npm install -g npm to update!               │
#    │                                                               │
#    ╰───────────────────────────────────────────────────────────────╯

# %%
! make test/unit
# Out:
# Running tests:
# ok  	github.com/integr8ly/integreatly-operator/apis/v1alpha1	0.079s	coverage: 3.4% of statements
# ?   	github.com/integr8ly/integreatly-operator/controllers/namespacelabel	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/controllers/rhmi	0.131s	coverage: 7.3% of statements
# ok  	github.com/integr8ly/integreatly-operator/controllers/subscription	25.125s	coverage: 56.9% of statements
# ok  	github.com/integr8ly/integreatly-operator/controllers/subscription/csvlocator	0.060s	coverage: 77.4% of statements
# ok  	github.com/integr8ly/integreatly-operator/controllers/subscription/rhmiConfigs	0.064s	coverage: 61.5% of statements
# ?   	github.com/integr8ly/integreatly-operator/controllers/tenant	[no test files]
# ?   	github.com/integr8ly/integreatly-operator/controllers/user	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/pkg/addon	0.137s	coverage: 75.4% of statements
# ?   	github.com/integr8ly/integreatly-operator/pkg/client	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/pkg/config	0.040s	coverage: 5.6% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/metrics	0.073s	coverage: 17.3% of statements
# ?   	github.com/integr8ly/integreatly-operator/pkg/products	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/cloudresources	0.069s	coverage: 6.8% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/grafana	0.080s	coverage: 4.8% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/marin3r	0.121s	coverage: 43.6% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/marin3r/config	0.052s	coverage: 43.5% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/monitoringcommon	0.099s	coverage: 85.9% of statements
# ?   	github.com/integr8ly/integreatly-operator/pkg/products/monitoringcommon/dashboards	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/monitoringspec	0.094s	coverage: 55.2% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/observability	0.107s	coverage: 30.8% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/rhsso	0.113s	coverage: 60.8% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/rhssocommon	0.140s	coverage: 37.9% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/rhssouser	0.132s	coverage: 57.5% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/products/threescale	0.569s	coverage: 49.6% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources	0.269s	coverage: 35.6% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/backup	7.141s	coverage: 85.7% of statements
# ?   	github.com/integr8ly/integreatly-operator/pkg/resources/catalogsource	[no test files]
# ?   	github.com/integr8ly/integreatly-operator/pkg/resources/constants	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/custom-domain	3.538s	coverage: 84.6% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/custom-smtp	0.062s	coverage: 72.0% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/events	0.043s	coverage: 100.0% of statements
# ?   	github.com/integr8ly/integreatly-operator/pkg/resources/k8s	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/logger	0.003s	coverage: 76.2% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/marketplace	0.085s	coverage: 32.4% of statements
# ?   	github.com/integr8ly/integreatly-operator/pkg/resources/owner	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/poddistribution	15.139s	coverage: 82.4% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/quota	0.065s	coverage: 61.6% of statements
# ?   	github.com/integr8ly/integreatly-operator/pkg/resources/ratelimit	[no test files]
# ?   	github.com/integr8ly/integreatly-operator/pkg/resources/rhmi	[no test files]
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/sts	0.071s	coverage: 66.7% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/resources/user	0.068s	coverage: 75.2% of statements
# ok  	github.com/integr8ly/integreatly-operator/pkg/webhooks	1.041s	coverage: 57.3% of statements

# %% [markdown]
# ## Building of images

# %%
! make image/build
# Out:
# GO111MODULE=off go get github.com/matryer/moq
# /home/jimfitz/go/src/github.com/integr8ly/integreatly-operator/bin/controller-gen object:headerFile="hack/boilerplate.go.txt" paths="./..."
# /home/jimfitz/go/src/github.com/integr8ly/integreatly-operator/bin/controller-gen rbac:roleName=manager-role crd webhook paths="./..." output:crd:artifacts:config=config/crd/bases
# mv ./config/crd/bases/integreatly.org_apimanagementtenants.yaml ./config/crd-sandbox/bases
# echo "build image quay.io/integreatly/managed-api-service:v1.30.0"
# build image quay.io/integreatly/managed-api-service:v1.30.0
# docker build --platform=linux/amd64 -t quay.io/integreatly/managed-api-service:v1.30.0 .
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# [1/2] STEP 1/12: FROM registry.ci.openshift.org/openshift/release:golang-1.18 AS builder
# Trying to pull registry.ci.openshift.org/openshift/release:golang-1.18...
# Getting image source signatures
# Copying blob b35e1f570b05 [------------] 0.0b / 344.3MiB (skipped: 0.0b = 0.00%)
# Copying blob b35e1f570b05 [------------------------------------] 0.0b / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [------------------------------------] 0.0b / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [------------------------------------] 0.0b / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [------------------------------------] 0.0b / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [------------------------------------] 0.0b / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [------------------------------------] 0.0b / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [---------------------------------] 32.0KiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [--------------------------------] 208.4KiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [--------------------------------] 400.4KiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [----------------------------------] 1.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [----------------------------------] 1.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [----------------------------------] 3.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [----------------------------------] 4.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [----------------------------------] 4.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>---------------------------------] 5.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>---------------------------------] 7.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>---------------------------------] 7.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>---------------------------------] 8.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>---------------------------------] 9.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 10.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 10.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 11.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 12.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 12.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 13.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 14.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 15.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [>--------------------------------] 15.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 16.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 17.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 17.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 18.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 19.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 20.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 20.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 21.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 22.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 22.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 23.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 24.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 25.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=>-------------------------------] 26.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 26.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 27.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 28.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 29.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 29.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 30.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 31.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 31.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 32.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 33.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 34.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 34.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 35.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==>------------------------------] 36.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 36.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 37.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 38.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 39.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 40.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 40.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 41.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 42.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 43.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 44.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 44.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 45.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===>-----------------------------] 46.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 47.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 47.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 48.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 49.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 50.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 50.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 51.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 52.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 52.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 53.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 54.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 54.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 54.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 55.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 55.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 56.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 56.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====>----------------------------] 57.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 57.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 58.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 58.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 59.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 60.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 60.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 61.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 61.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 62.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 62.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 63.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 63.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 64.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 64.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 65.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 65.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 66.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 67.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====>---------------------------] 67.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 67.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 68.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 69.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 69.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 69.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 70.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 70.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 71.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 71.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 72.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 72.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 73.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 73.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 73.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 74.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 74.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 75.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 75.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 76.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 76.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 77.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 77.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======>--------------------------] 78.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 78.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 78.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 79.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 79.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 80.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 80.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 81.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 81.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 82.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 82.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 82.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 83.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 83.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 84.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 84.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 84.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 85.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 86.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 86.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 86.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 86.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 87.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 87.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 87.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======>-------------------------] 88.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 89.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 89.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 90.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 90.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 91.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 91.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 92.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 92.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 93.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 93.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 94.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 95.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 95.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 96.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 96.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 97.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 97.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 98.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>------------------------] 99.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>-----------------------] 99.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>-----------------------] 100.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>-----------------------] 101.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========>-----------------------] 102.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 102.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 103.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 104.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 104.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 105.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 106.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 107.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 107.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 108.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 110.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 111.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========>----------------------] 112.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 113.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 114.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 115.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 117.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 118.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 119.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 120.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 121.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========>---------------------] 122.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 124.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 125.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 126.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 127.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 128.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 129.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 131.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 132.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========>--------------------] 133.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 134.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 135.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 136.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 138.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 139.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 140.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 141.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 142.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 143.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============>-------------------] 145.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 146.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 147.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 148.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 149.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 150.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 152.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 153.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 154.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============>------------------] 155.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 156.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 157.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 159.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 160.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 161.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 162.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 163.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 164.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============>-----------------] 166.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 167.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 168.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 169.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 170.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 171.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 172.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 174.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 175.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============>----------------] 176.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 177.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 178.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 179.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 180.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 182.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 183.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 184.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 185.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 186.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 186.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [================>---------------] 187.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 188.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 189.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 191.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 192.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 193.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 194.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 195.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 196.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=================>--------------] 198.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 199.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 200.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 201.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 202.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 203.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 204.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 206.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 207.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 208.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==================>-------------] 209.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 210.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 211.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 213.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 214.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 215.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 216.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 217.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 218.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===================>------------] 220.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 221.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 222.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 223.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 224.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 226.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 227.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 228.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 229.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [====================>-----------] 230.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 231.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 232.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 234.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 235.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 236.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 237.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 238.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 239.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=====================>----------] 241.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 242.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 243.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 244.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 245.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 246.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 248.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 249.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 250.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 251.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [======================>---------] 252.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 253.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 255.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 256.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 257.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 258.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 259.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 260.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 262.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=======================>--------] 263.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 264.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 264.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 265.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 266.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 267.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 268.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 269.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 270.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 272.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [========================>-------] 273.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 274.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 275.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 276.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 277.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 279.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 280.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 281.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 282.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 283.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=========================>------] 284.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 286.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 287.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 288.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 289.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 290.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 291.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 293.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 294.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==========================>-----] 295.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 296.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 297.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 298.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 298.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 299.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 300.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 302.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 303.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 304.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===========================>----] 305.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 306.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 307.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 309.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 310.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 311.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 312.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 313.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 314.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 316.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [============================>---] 317.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 318.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 319.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 320.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 321.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 323.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 324.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 325.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 326.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [=============================>--] 327.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 328.8MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 330.0MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 331.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 332.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 333.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 334.6MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 335.7MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 336.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [==============================>-] 338.1MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============================>] 339.3MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============================>] 340.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============================>] 340.9MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============================>] 341.2MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============================>] 342.4MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 [===============================>] 343.5MiB / 344.3MiB
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying blob b35e1f570b05 done
# Copying blob 2d473b07cdd5 skipped: already exists
# Copying config 366d4bfa92 done
# Writing manifest to image destination
# Storing signatures
# [1/2] STEP 2/12: WORKDIR /workspace
# --> 0112c1addf1
# [1/2] STEP 3/12: COPY go.mod go.mod
# --> 011f2ac8d1c
# [1/2] STEP 4/12: COPY go.sum go.sum
# --> 50d03b264e3
# [1/2] STEP 5/12: COPY vendor/ vendor/
# --> a28c7cca71b
# [1/2] STEP 6/12: COPY main.go main.go
# --> 52d8d7e05b8
# [1/2] STEP 7/12: COPY apis/ apis/
# --> 2f83cd2b4bf
# [1/2] STEP 8/12: COPY controllers/ controllers/
# --> 8070d4aa748
# [1/2] STEP 9/12: COPY pkg/ pkg/
# --> 3fe7f8b77f0
# [1/2] STEP 10/12: COPY version/ version/
# --> fc2fae11e88
# [1/2] STEP 11/12: COPY test/ test/
# --> 5f64b550be3
# [1/2] STEP 12/12: RUN CGO_ENABLED=0 GOOS=linux GOARCH=amd64 go build -a -o rhmi-operator main.go
# --> cc10e97d556
# [2/2] STEP 1/10: FROM registry.access.redhat.com/ubi8/ubi-minimal:latest
# [2/2] STEP 2/10: ENV OPERATOR=/usr/local/bin/rhmi-operator     USER_UID=1001     USER_NAME=integreatly-operator
# --> e5d53b78725
# [2/2] STEP 3/10: COPY --from=builder /workspace/rhmi-operator /usr/local/bin/rhmi-operator
# --> fa23bc8e595
# [2/2] STEP 4/10: COPY templates /templates
# --> 99c4ef49162
# [2/2] STEP 5/10: COPY manifests /manifests
# --> 5cea196a49c
# [2/2] STEP 6/10: COPY products /products
# --> 1adf0129c4a
# [2/2] STEP 7/10: COPY build/bin /usr/local/bin
# --> 94735c45c5b
# [2/2] STEP 8/10: RUN /usr/local/bin/user_setup
# + mkdir -p /root
# + chown 1001:0 /root
# + chmod ug+rwx /root
# + chmod g+rw /etc/passwd
# + rm /usr/local/bin/user_setup
# --> f2834d316e8
# [2/2] STEP 9/10: ENTRYPOINT ["/usr/local/bin/entrypoint"]
# --> d50444c5be0
# [2/2] STEP 10/10: USER ${USER_UID}
# [2/2] COMMIT quay.io/integreatly/managed-api-service:v1.30.0
# --> b4a41c7aee4
# [Warning] one or more build args were not consumed: [TARGETARCH TARGETOS TARGETPLATFORM]
# Successfully tagged quay.io/integreatly/managed-api-service:v1.30.0
# b4a41c7aee4addacf8d4d1a7c8ab7f3fcc6f77c3d4fa01e4b0d34d2feee92f1a

# %%
! make image/functional/build

# %%
! make image/osde2e/build

# %%
! make scorecard/build
# Out:
# docker build --platform=linux/amd64 -t quay.io/integreatly/scorecard-test-kuttl:master -f Dockerfile.scorecard .
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# [1/2] STEP 1/9: FROM registry.ci.openshift.org/openshift/release:golang-1.18 AS builder
# [1/2] STEP 2/9: WORKDIR /workspace
# --> Using cache 0112c1addf130734b460a682584093699266b4993d081e1bc1efc42d765e0305
# --> 0112c1addf1
# [1/2] STEP 3/9: COPY go.mod ./go.mod
# --> ff05f33aec3
# [1/2] STEP 4/9: COPY go.sum ./go.sum
# --> b374fb88447
# [1/2] STEP 5/9: COPY vendor ./vendor
# --> 5b649709a87
# [1/2] STEP 6/9: COPY make ./make
# --> 4ae8affcc70
# [1/2] STEP 7/9: COPY Makefile ./Makefile
# --> 2cff82d7d85
# [1/2] STEP 8/9: COPY test/scorecard ./test/scorecard
# --> e9c0430553e
# [1/2] STEP 9/9: RUN GOOS=linux GOARCH=amd64 make scorecard/compile
# cat: apis/v1alpha1/rhmi_types.go: No such file or directory
# find: 'manifests/': No such file or directory
# find: 'manifests/': No such file or directory
# go build -o scorecard-test-kuttl test/scorecard/main.go
# --> 1d5ca808acd
# [2/2] STEP 1/11: FROM registry.access.redhat.com/ubi8/ubi-minimal:latest
# [2/2] STEP 2/11: RUN curl -Lso /usr/local/bin/kubectl https://storage.googleapis.com/kubernetes-release/release/v1.18.0/bin/linux/amd64/kubectl
# --> 369308a5379
# [2/2] STEP 3/11: RUN curl -Lso /usr/local/bin/kubectl-kuttl https://github.com/kudobuilder/kuttl/releases/download/v0.11.1/kubectl-kuttl_0.11.1_linux_x86_64
# --> 6377ba8d0cb
# [2/2] STEP 4/11: RUN chmod +x /usr/local/bin/*
# --> 970c5372e7e
# [2/2] STEP 5/11: ENV HOME=/opt/scorecard-test-kuttl     USER_NAME=scorecard-test-kuttl     USER_UID=1001     KUBECONFIG=
# --> 7254748bae3
# [2/2] STEP 6/11: RUN echo "${USER_NAME}:x:${USER_UID}:0:${USER_NAME} user:${HOME}:/sbin/nologin" >> /etc/passwd
# --> 1e19c82e698
# [2/2] STEP 7/11: WORKDIR ${HOME}
# --> ff6df3014c9
# [2/2] STEP 8/11: COPY --from=builder /workspace/scorecard-test-kuttl /usr/local/bin/scorecard-test-kuttl
# --> 3111adfff16
# [2/2] STEP 9/11: COPY --from=builder /workspace/test/scorecard/entrypoint /usr/local/bin/entrypoint
# --> f7877b49275
# [2/2] STEP 10/11: ENTRYPOINT ["/usr/local/bin/entrypoint"]
# --> 0015e99c16b
# [2/2] STEP 11/11: USER ${USER_UID}
# [2/2] COMMIT quay.io/integreatly/scorecard-test-kuttl:master
# --> 6a866d29708
# [Warning] one or more build args were not consumed: [TARGETARCH TARGETOS TARGETPLATFORM]
# Successfully tagged quay.io/integreatly/scorecard-test-kuttl:master
# 6a866d29708d2b54deb430c63603f518b5cf259683f2fc010c96d2e4927462a7
